# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.12/dist-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.24.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (26.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.4.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 21.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import re
import nltk
import spacy

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
Natural Language Processing, also known as NLP, is one of the most important areas of Artificial Intelligence.
Today, companies use NLP in chatbots, search engines, recommendation systems, social media analytics,
customer feedback analysis, automatic translation, and voice assistants.

In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
online forms, tweets, product comments, and support tickets. However, this text data is often messy.
For example, a customer may write: "I LOVE this product!!! Visit https://example.com/product123 #Amazing #AI".
Another user may write: "The service was not good... I waited 45 minutes and no one replied."

Before applying machine learning or deep learning models, we need to clean and prepare the text.
This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
stemming, lemmatization, and sometimes removing emojis or special characters.

Good preprocessing can improve the quality of NLP models. However, preprocessing should be done carefully.
For example, removing the word "not" from the sentence "I am not happy" can change the meaning completely.
Similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
can contain useful information about topics, opinions, or trends.
"""

print(text)
# Out:
# Natural Language Processing, also known as NLP, is one of the most important areas of Artificial Intelligence.
# Today, companies use NLP in chatbots, search engines, recommendation systems, social media analytics,
# customer feedback analysis, automatic translation, and voice assistants.
#
# In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
# online forms, tweets, product comments, and support tickets. However, this text data is often messy.
# For example, a customer may write: "I LOVE this product!!! Visit https://example.com/product123 #Amazing #AI".
# Another user may write: "The service was not good... I waited 45 minutes and no one replied."
#
# Before applying machine learning or deep learning models, we need to clean and prepare the text.
# This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
# removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
# stemming, lemmatization, and sometimes removing emojis or special characters.
#
# Good preprocessing can improve the quality of NLP models. However, preprocessing should be done carefully.
# For example, removing the word "not" from the sentence "I am not happy" can change the meaning completely.
# Similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
# can contain useful information about topics, opinions, or trends.

# %%
text = re.sub(r'#\w+', '', text)

# %%
text = re.sub(r'[^\x00-\x7F]+', '', text)

# %%
print(text)
# Out:
# Natural Language Processing, also known as NLP, is one of the most important areas of Artificial Intelligence.
# Today, companies use NLP in chatbots, search engines, recommendation systems, social media analytics,
# customer feedback analysis, automatic translation, and voice assistants.
#
# In 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
# online forms, tweets, product comments, and support tickets. However, this text data is often messy.
# For example, a customer may write: "I LOVE this product!!! Visit https://example.com/product123  ".
# Another user may write: "The service was not good... I waited 45 minutes and no one replied."
#
# Before applying machine learning or deep learning models, we need to clean and prepare the text.
# This step is called text preprocessing. It may include converting text to lowercase, removing URLs,
# removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
# stemming, lemmatization, and sometimes removing emojis or special characters.
#
# Good preprocessing can improve the quality of NLP models. However, preprocessing should be done carefully.
# For example, removing the word "not" from the sentence "I am not happy" can change the meaning completely.
# Similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
# can contain useful information about topics, opinions, or trends.

# %%
lower_text = text.lower()
print("Lowercase Text:\n")
print(lower_text)
# Out:
# Lowercase Text:
#
#
# natural language processing, also known as nlp, is one of the most important areas of artificial intelligence.
# today, companies use nlp in chatbots, search engines, recommendation systems, social media analytics,
# customer feedback analysis, automatic translation, and voice assistants.
#
# in 2026, many organizations are collecting huge amounts of text data from websites, emails, reviews,
# online forms, tweets, product comments, and support tickets. however, this text data is often messy.
# for example, a customer may write: "i love this product!!! visit https://example.com/product123  ".
# another user may write: "the service was not good... i waited 45 minutes and no one replied."
#
# before applying machine learning or deep learning models, we need to clean and prepare the text.
# this step is called text preprocessing. it may include converting text to lowercase, removing urls,
# removing punctuation, removing numbers, tokenizing sentences into words, removing stop words,
# stemming, lemmatization, and sometimes removing emojis or special characters.
#
# good preprocessing can improve the quality of nlp models. however, preprocessing should be done carefully.
# for example, removing the word "not" from the sentence "i am not happy" can change the meaning completely.
# similarly, removing hashtags may not always be a good idea in social media analytics because hashtags
# can contain useful information about topics, opinions, or trends.

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokens = word_tokenize(lower_text)
print("Tokenized Words:\n")
print(tokens)
# Out:
# Tokenized Words:
#
# ['natural', 'language', 'processing', ',', 'also', 'known', 'as', 'nlp', ',', 'is', 'one', 'of', 'the', 'most', 'important', 'areas', 'of', 'artificial', 'intelligence', '.', 'today', ',', 'companies', 'use', 'nlp', 'in', 'chatbots', ',', 'search', 'engines', ',', 'recommendation', 'systems', ',', 'social', 'media', 'analytics', ',', 'customer', 'feedback', 'analysis', ',', 'automatic', 'translation', ',', 'and', 'voice', 'assistants', '.', 'in', '2026', ',', 'many', 'organizations', 'are', 'collecting', 'huge', 'amounts', 'of', 'text', 'data', 'from', 'websites', ',', 'emails', ',', 'reviews', ',', 'online', 'forms', ',', 'tweets', ',', 'product', 'comments', ',', 'and', 'support', 'tickets', '.', 'however', ',', 'this', 'text', 'data', 'is', 'often', 'messy', '.', 'for', 'example', ',', 'a', 'customer', 'may', 'write', ':', '``', 'i', 'love', 'this', 'product', '!', '!', '!', 'visit', 'https', ':', '//example.com/product123', '``', '.', 'another', 'user', 'may', 'write', ':', '``', 'the', 'service', 'was', 'not', 'good', '...', 'i', 'waited', '45', 'minutes', 'and', 'no', 'one', 'replied', '.', "''", 'before', 'applying', 'machine', 'learning', 'or', 'deep', 'learning', 'models', ',', 'we', 'need', 'to', 'clean', 'and', 'prepare', 'the', 'text', '.', 'this', 'step', 'is', 'called', 'text', 'preprocessing', '.', 'it', 'may', 'include', 'converting', 'text', 'to', 'lowercase', ',', 'removing', 'urls', ',', 'removing', 'punctuation', ',', 'removing', 'numbers', ',', 'tokenizing', 'sentences', 'into', 'words', ',', 'removing', 'stop', 'words', ',', 'stemming', ',', 'lemmatization', ',', 'and', 'sometimes', 'removing', 'emojis', 'or', 'special', 'characters', '.', 'good', 'preprocessing', 'can', 'improve', 'the', 'quality', 'of', 'nlp', 'models', '.', 'however', ',', 'preprocessing', 'should', 'be', 'done', 'carefully', '.', 'for', 'example', ',', 'removing', 'the', 'word', '``', 'not', "''", 'from', 'the', 'sentence', '``', 'i', 'am', 'not', 'happy', "''", 'can', 'change', 'the', 'meaning', 'completely', '.', 'similarly', ',', 'removing', 'hashtags', 'may', 'not', 'always', 'be', 'a', 'good', 'idea', 'in', 'social', 'media', 'analytics', 'because', 'hashtags', 'can', 'contain', 'useful', 'information', 'about', 'topics', ',', 'opinions', ',', 'or', 'trends', '.']

# %%
stop_words = set(stopwords.words('english'))
important_words = {"not", "no"}
filtered_tokens = [
    word for word in tokens
    if word.isalpha() and (word not in stop_words or word in important_words)
]
print("After Stopword Removal:\n")
print(filtered_tokens)
# Out:
# After Stopword Removal:
#
# ['natural', 'language', 'processing', 'also', 'known', 'nlp', 'one', 'important', 'areas', 'artificial', 'intelligence', 'today', 'companies', 'use', 'nlp', 'chatbots', 'search', 'engines', 'recommendation', 'systems', 'social', 'media', 'analytics', 'customer', 'feedback', 'analysis', 'automatic', 'translation', 'voice', 'assistants', 'many', 'organizations', 'collecting', 'huge', 'amounts', 'text', 'data', 'websites', 'emails', 'reviews', 'online', 'forms', 'tweets', 'product', 'comments', 'support', 'tickets', 'however', 'text', 'data', 'often', 'messy', 'example', 'customer', 'may', 'write', 'love', 'product', 'visit', 'https', 'another', 'user', 'may', 'write', 'service', 'not', 'good', 'waited', 'minutes', 'no', 'one', 'replied', 'applying', 'machine', 'learning', 'deep', 'learning', 'models', 'need', 'clean', 'prepare', 'text', 'step', 'called', 'text', 'preprocessing', 'may', 'include', 'converting', 'text', 'lowercase', 'removing', 'urls', 'removing', 'punctuation', 'removing', 'numbers', 'tokenizing', 'sentences', 'words', 'removing', 'stop', 'words', 'stemming', 'lemmatization', 'sometimes', 'removing', 'emojis', 'special', 'characters', 'good', 'preprocessing', 'improve', 'quality', 'nlp', 'models', 'however', 'preprocessing', 'done', 'carefully', 'example', 'removing', 'word', 'not', 'sentence', 'not', 'happy', 'change', 'meaning', 'completely', 'similarly', 'removing', 'hashtags', 'may', 'not', 'always', 'good', 'idea', 'social', 'media', 'analytics', 'hashtags', 'contain', 'useful', 'information', 'topics', 'opinions', 'trends']

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
